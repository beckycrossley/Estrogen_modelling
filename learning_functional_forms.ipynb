# %%
import pandas as pd

df = pd.read_csv("data/Freay1997Fig1.csv")

print(df.head())
# Out:
#    Time (minutes)  Scaled constriction level
# 0        0.000000                   0.000000
# 1        3.192663                   0.007126
# 2        3.678900                   0.172253
# 3        5.660661                   0.307961
# 4        9.456345                   0.404935
